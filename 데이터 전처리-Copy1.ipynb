# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %%
class Oil:
    def __init__(self):
        self.data = pd.read_csv('refined_data/data.csv')
        self.standard = ''
        self.do = ''
        self.sigungu = ''
        self.x = ''
        self.y = ''
        
    def set_standard(self,string):
        self.column = string
        
    def get_standard(self):
        return self.standard     
    
    def set_do(self,string):
        self.do = string
        
    def get_do(self,string):
        return self.do
        
    def set_sigungu(self,string):
        self.sigungu = string
        
    def get_sigungu(self,string):
        return self.sigungu
    
    def set_plot_size(self,x,y):
        self.x = ''
        self.y = ''
        
    def get_plot_size(self):
        return rc
        
    def show_plot(self):
        plt.show()

# %%
plt.rcParams["figure.figsize"]
# Out:
# [6.0, 4.0]

# %%
data['지역'].unique()
# Out:
# array(['강원 강릉시', '강원 고성군', '강원 동해시', '강원 삼척시', '강원 속초시', '강원 양구군',
#        '강원 양양군', '강원 영월군', '강원 원주시', '강원 인제군', '강원 정선군', '강원 철원군',
#        '강원 춘천시', '강원 태백시', '강원 평창군', '강원 홍천군', '강원 화천군', '강원 횡성군',
#        '경기 가평군', '경기 고양시', '경기 과천시', '경기 광명시', '경기 광주시', '경기 구리시',
#        '경기 군포시', '경기 김포시', '경기 남양주시', '경기 동두천시', '경기 부천시', '경기 성남시',
#        '경기 수원시', '경기 시흥시', '경기 안산시', '경기 안성시', '경기 안양시', '경기 양주시',
#        '경기 양평군', '경기 여주시', '경기 연천군', '경기 오산시', '경기 용인시', '경기 의왕시',
#        '경기 의정부시', '경기 이천시', '경기 파주시', '경기 평택시', '경기 포천시', '경기 하남시',
#        '경기 화성시', '경남 거제시', '경남 거창군', '경남 고성군', '경남 김해시', '경남 남해군',
#        '경남 밀양시', '경남 사천시', '경남 산청군', '경남 양산시', '경남 의령군', '경남 진주시',
#        '경남 창녕군', '경남 창원시', '경남 통영시', '경남 하동군', '경남 함안군', '경남 함양군',
#        '경남 합천군', '경북 경산시', '경북 경주시', '경북 고령군', '경북 구미시', '경북 군위군',
#        '경북 김천시', '경북 문경시', '경북 봉화군', '경북 상주시', '경북 성주군', '경북 안동시',
#        '경북 영덕군', '경북 영양군', '경북 영주시', '경북 영천시', '경북 예천군', '경북 울릉군',
# ...

# %%
loc_array = list(data.groupby(['기간']).groups.keys())
X = data.loc[data.groupby(['기간']).groups[loc_array[0]]]
X = X[X['휘발유'] != 0]
X = X[X['경유'] != 0]

# %%
sns.set(font='Gulim', font_scale=1) # Seaborn 설정

# %%
plt.rcParams["figure.figsize"] = (14,8)
plt.rcParams['path.simplify_threshold'] = 1.0
X1 = X[X['지역'].str.contains('충북')]
X1.reset_index(drop=True,inplace=True)
plt.scatter(X1[:]['경유'],X1[:]['휘발유'],c='red',label='충북', s=10)
X2 = X[X['지역'].str.contains('충남')]
X2.reset_index(drop=True,inplace=True)
plt.scatter(X2[:]['경유'],X2[:]['휘발유'],c='blue',label='충남', s=10)
X3 = X[X['지역'].str.contains('경북')]
X3.reset_index(drop=True,inplace=True)
plt.scatter(X3[:]['경유'],X3[:]['휘발유'],c='yellow',label='경북', s=10)
X4 = X[X['지역'].str.contains('경남')]
X4.reset_index(drop=True,inplace=True)
plt.scatter(X4[:]['경유'],X4[:]['휘발유'],c='black',label='경남', s=10)
X5 = X[X['지역'].str.contains('경기')]
X5.reset_index(drop=True,inplace=True)
plt.scatter(X5[:]['경유'],X5[:]['휘발유'],c='orange',label='경기', s=10)
X6 = X[X['지역'].str.contains('서울')]
X6.reset_index(drop=True,inplace=True)
plt.scatter(X6[:]['경유'],X6[:]['휘발유'],c='green',label='서울', s=10)
X7 = X[X['지역'].str.contains('인천')]
X7.reset_index(drop=True,inplace=True)
plt.scatter(X7[:]['경유'],X7[:]['휘발유'],c='purple',label='인천', s=10)
X8 = X[X['지역'].str.contains('울산')]
X8.reset_index(drop=True,inplace=True)
plt.scatter(X8[:]['경유'],X8[:]['휘발유'],c='gray',label='울산', s=10)
X9 = X[X['지역'].str.contains('전남')]
X9.reset_index(drop=True,inplace=True)
plt.scatter(X9[:]['경유'],X9[:]['휘발유'],c='white',label='전남', s=10)
X10 = X[X['지역'].str.contains('전북')]
X10.reset_index(drop=True,inplace=True)
plt.scatter(X10[:]['경유'],X10[:]['휘발유'],c='brown',label='전북', s=10)
plt.xlabel('경유 가격(원)')
plt.ylabel('휘발유 가격(원)')
plt.title('기름값 분포')
plt.grid(False)
plt.legend()
plt.show()

# %%
data[data['휘발유'] < 1060]
# Out:
#                번호      지역                 상호                         주소  \
# 2257274  A0024719  경북 포항시  현대오일뱅크㈜직영 포항셀프주유소  경북 포항시 남구 새천년대로 410 (대잠동)
#
#                기간     상표 셀프여부  고급휘발유   휘발유   경유  실내등유
# 2257274  20200510  SK에너지   셀프      0  1059  979     0

# %%
data.loc[data.groupby(['기간']).groups[loc_array[0]]]
# Out:
#               번호      지역           상호                    주소        기간      상표  \
# 0       A0010562  강원 강릉시  (주)동해에너지주유소  강원 강릉시 경강로 2101(임당동)  20201014   SK에너지
# 0       A0010562  강원 강릉시  (주)동해에너지주유소  강원 강릉시 경강로 2101(임당동)  20200914   SK에너지
# 0       A0010562  강원 강릉시  (주)동해에너지주유소  강원 강릉시 경강로 2101(임당동)  20200814   SK에너지
# 0       A0010562  강원 강릉시  (주)동해에너지주유소  강원 강릉시 경강로 2101(임당동)  20200714   SK에너지
# 0       A0010562  강원 강릉시  (주)동해에너지주유소  강원 강릉시 경강로 2101(임당동)  20200614   SK에너지
# ...          ...     ...          ...                   ...       ...     ...
# 344129  A0012382  충북 진천군        화랑주유소   충북 진천군 진천읍 백곡로 1522  20200606  현대오일뱅크
# 344129  A0012092  충북 진천군        대죽주유소    충북 진천군 백곡면 백곡로 522  20200322  현대오일뱅크
# 344129  A0009529  충북 진천군    대명주유소(SK)    충북 진천군 진천읍 문화로 633  20200211   SK에너지
# 344129  A0012215  충북 진천군        덕산주유소    충북 진천군 덕산면 덕금로 778  20191229   SK에너지
# 344129  A0013418  충북 충주시        희망주유소       충북 충주시 금봉대로 398  20191114   GS칼텍스
#
# ...

# %%
plt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cd653b2c8062> in <module>
# ----> 1 plt
#
# NameError: name 'plt' is not defined
